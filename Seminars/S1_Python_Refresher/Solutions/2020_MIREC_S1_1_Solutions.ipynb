# %% [markdown]
# МИРЭК | 4 модуль
#
# *Авторы: Алла Тамбовцева, Татьяна Рогович*
#
# # Основы программирования в Python
#
# ### Cеминар 1
# ### Решение задач по темам лекции 1
#
# *Примечание: под программой в заданиях подразумевается просто блок работающего кода, который выполняет нужную задачу. Для удобства можно считать, что одна ячейка с кодом – это одна программа.*

# %% [markdown]
# ### Задание 0 (вычислительное)
#
# Посчитайте:
#
# * $\log(25)$, $\log(\exp(3))$, $\log_{10}1000$;
# * $\pi^3$, $123^4$;
# * $\sqrt{459}$.
#
# Пользуйтесь библиотекой math

# %%
import math

# пункт 1
print(math.log(25))
print(math.log(math.exp(3)))
print(math.log(1000, 10))  # на самом деле ровно 3 – опять история про формат float
print(math.log10(1000))  # альтернатива строке выше

# пункт 2
print(math.pi ** 3)
print(123 ** 4)

# пункт 3
print(math.sqrt(459))
print(459 ** 0.5)  # альтернатива коду выше
# Out:
# 3.2188758248682006
# 3.0
# 2.9999999999999996
# 3.0
# 31.006276680299816
# 228886641
# 21.42428528562855
# 21.42428528562855

# %% [markdown]
# ### Задание 1 (стартовое)
#
# В переменных `a` и `b` хранятся некоторые числа. Напишите код, который бы менял значения переменных местами. Создавать вспомогательные переменные *можно*.
#
# **Пример:**

# %%
# до
a = 2
b = 5

# %%
# после
print(a)
print(b)
# Out:
# 5
# 2

# %%
c = a
a = b
b = c
print(a)
print(b)
# Out:
# 5
# 2

# %% [markdown]
# Еще в Python можно решить эту задачу через множественное присваивание, без создания третьей переменной:

# %%
a = 2
b = 5
a, b = b, a
print(a, b)
# Out:
# 5 2

# %% [markdown]
# ### Задание 2 (экономическое)
#
# Напишите программу, которая логарифмирует значение ВВП, которое хранится в переменной `gdp` и округляет результат до второго знака после запятой.

# %%
gdp = 4500000
log_gdp = round(math.log(gdp), 2) 
log_gdp
# Out:
# 15.32

# %% [markdown]
# На семинаре мы еще рассмотрели иной вариант решения, в предположении, что нам не важно, в каком виде будет храниться результат, а важно, как он будет отображен на экране. То есть, с применением форматирования строк:

# %%
gdp = 4500000
log_gdp = math.log(gdp)
print("%.2f"%log_gdp)
# Out:
# 15.32

# %% [markdown]
# ### Задание 3 (политологическое)
#
# В переменной `fh` хранится значение индекса политической свободы *Freedom House*, а в переменной `p`
# значение индекса Polity IV. Напишите программу, которая будет считать индекс `Freedom`:
#
# $$
# \text{Freedom} = 0.4 \cdot \text{Freedom House} + 0.6 \cdot \text{Polity IV}
# $$

# %%
fh = 8
p = 2
Freedom = 0.4 * 8 + 0.6 * 2
print(Freedom)
# Out:
# 4.4

# %% [markdown]
# ### Задание 4 (весеннее)
#
# С приходом весны питон решил каждый день выползать погреться на солнышко. Однако он знал, что солнце весной довольно активное, и поэтому разработал такую схему: в первый день он греется одну минуту, а в каждый последующий день увеличивает время пребывания на солнце на 3 минуты. Напишите код, который позволит вычислять, сколько минут питон будет тратить на солнечные ванны в некоторый выбранный день.
#
# *Внимание:* ваш код должен выводить номер дня и число минут. Использовать циклы нельзя, в задании предполагается многократный запуск ячеек с кодом.
#
# Если хочется избежать многократного запуска ячейки с кодом (что оправдано), попробуйте решить эту задачу без повторного запуска ячейки и при этом без цикла, предполагая, что пользователь с клавиатуры вводит номер интересующего его дня, а на экран выводится соответствующее число минут.

# %%
# решение 1 – с многократным запуском следующей ячейки
i = 1
day = 1

# %%
i = i + 1
day = day + 3
print(i, day)
# Out:
# 2 4

# %%
# решение 2 – запрашиваем номер дня у пользователя и выводим результат – число минут
n = int(input("Enter day number: "))
res = 1 + 3 * (n - 1)
print(res)
# Out:
# Enter day number: 5
# 13

# %% [markdown]
# ### Задание 5 (приветственное)
#
# Напишите программу, которая запрашивает у пользователя имя и фамилию и выводит на экран сообщение

# %%
name = input("Enter name: ")
surname = input("Enter surname: ")
# Out:
# Enter name: Alla
# Enter surname: T

# %%
# решение 1 – без форматирования строк, но с выбором разделителя
print(name, " ", surname, ", добро пожаловать!", sep="")
# Out:
# Alla T, добро пожаловать!

# %%
# решение 2 – с f-строками
print(f"{name} {surname}, добро пожаловать!")
# Out:
# Alla T, добро пожаловать!

# %%
# решение 3 – с «классическим» форматированием строк
print("%s %s, добро пожаловать!" %(name, surname))
# Out:
# Alla T, добро пожаловать!

# %% [markdown]
# ```Имя Фамилия```, добро пожаловать!

# %% [markdown]
# ### Задание 6 (биологическое)
#
# Напишите программу, которая запрашивает у пользователя с клавиатуры его рост в сантиметрах, его вес в килограммах (каждый показатель – с новой строки, в новом запросе) и выводит на экран сообщение вида:
#
#     Индекс массы тела: [значение].
#
# где вместо `[значение]` подставляется посчитанное значение индекса массы тела.
#
# Индекс массы тела считается так:
#
# $$
# \text{BMI} = \text{m} / \text{h}^2,
# $$
#
# где `m` – масса тела в килограммах, `h` – рост *в метрах*.

# %%
height = int(input("Enter your height: "))
weight = int(input("Enter your weight: "))
bmi = weight / (height / 100) ** 2
# Out:
# Enter your height: 168
# Enter your weight: 56

# %%
# решение 1 – без форматирования строк, но с выбором разделителя
print("Индекс массы тела: ", bmi, ".", sep="")
# Out:
# Индекс массы тела: 19.841269841269845.

# %%
# решение 2 – с f-строками
print(f"Индекс массы тела: {bmi}.")
# Out:
# Индекс массы тела: 19.841269841269845.

# %%
# решение 3 – с «классическим» форматированием строк
print("Индекс массы тела: %f." %bmi)
# Out:
# Индекс массы тела: 19.841270.

# %% [markdown]
# ### Задание 7 (рейтинговое)
#
# Дан список `student = ('Иван Питонов', 2001, [8, 7, 7, 9, 6], True)`. Выполните пункты ниже. Все выводы должны быть в формате "Средний балл студента: {средний балл}"
#
# 1. Выведите фамилию и имя Ивана в формате "Студент: {Фамилия}, {Имя}"
# 2. Выведите возраст Ивана, если сейчас 2020 год.
# 3. Напечатайте оценки Ивана через запятую.
# 1. Найдите средний балл Ивана, если оценки хранятся в списке внутри кортежа. Сумму элементов списка можно найти с помощью функции sum(). Выведите средний балл.
# 3. Если средняя оценка Ивана больше или равна 8, то он получает повышенную стипендию. Выведите True или False.

# %%
# ваше решение здесь

student = ('Иван Питонов', 2001, [8, 7, 7, 9, 6], True)
average =  sum(student[2]) / len(student[2])
print(f'Студент: {student[0].split()[1]}, {student[0].split()[0]}')
print(f'Возраст: {2020 - student[1]}')
print('Оценки: ', end = ' ')
print(*student[2], sep=',')
print(f'Средний балл студента: {average}')
print(f'Повышенная стипендия: {average >= 8}')
# Out:
# Студент: Питонов, Иван
# Возраст: 19
# Оценки:  8,7,7,9,6
# Средний балл студента: 7.4
# Повышенная стипендия: False

# %% [markdown]
# ### Задание 8 (сортировочное)
#
# Дан список `numbers = [1, 1000, 1002124, 25, 10, 20, 351]`. Выполните следующие шаги. Для сортировок пользуйтесь функцией sorted().
#
# 1. Отсортируйте этот список по возрастанию и сохраните результат в переменную numbers_int_sorted
# 2. На основе оригинального списка numbers с помощью функции map создайте новый список, где вместо каждого числа будет строка ('1', '1000' и т.д.) и сохраните его в переменную numbers_str
# 3. Отсортируйте список numbers_str по возрастанию и сохраните результат в переменную numbers_str_sorted
# 4. Отсортийте список numbers_str по возрастанию с помощью ключа, который перед сортировкой представляет строки в виде целых чисел, и сохраните результат в переменную numbers_str_key_sorted
# 5. Выведите три отсортированных списка. Есть ли среди них одинаковые? Почему?

# %%
# ваше решение здесь
numbers = [1, 1000, 1002124, 25, 10, 20, 351]
numbers_ints_sorted = sorted(numbers)
print(numbers_ints_sorted)
numbers_str = list(map(str, numbers))
numbers_str_sorted = sorted(numbers_str)
print(numbers_str_sorted)
numbers_str_key_sorted = sorted(numbers_str, key=int)
print(numbers_str_key_sorted)
# Out:
# [1, 10, 20, 25, 351, 1000, 1002124]
# ['1', '10', '1000', '1002124', '20', '25', '351']
# ['1', '10', '20', '25', '351', '1000', '1002124']

# %% [markdown]
# ### Задание 9 (логическое)
#
# Даны три целых числа. Определите, сколько среди них совпадающих. Программа должна вывести одно из чисел: 3 (если все совпадают), 2 (если два совпадает) или 0 (если все числа различны).
#
# **Формат ввода**
# Вводятся три целых числа
#
# **Формат вывода**
# Целое число

# %%
# место для решения
a = int(input())
b = int(input())
c = int(input())

if a == b == c:
    print(3)
elif a == b or a == c or b == c:
    print(2)
else:
    print(0)
# Out:
# 3

# %% [markdown]
# ### Задание 10 (зацикленное)
#
# Дано целое число, не меньшее 2. Выведите его наименьший натуральный делитель, отличный от 1.
#
# **Формат ввода**
# Вводится целое положительное число
#
# **Формат вывода**
# Выведите ответ на задачу
#
# **Пример**
#
# **Ввод**
# 15
#
# **Вывод**
# 3

# %%
# место для решения

x = int(input())
number = 2

while number <= x:
    if x % number == 0:
        print(number)
        break
    else:
        number += 1
# Out:
# 2

# %% [markdown]
# ### Задание 10 (счастливое)
# *задача из пробного варианта контрольной*
#
# Вася увлёкся нумерологией и теперь пытается найти взаимосвязь между датой и событиями, происходящими в тот или иной день.
# Так как Вася пока только начинает познавать все тонкости нумерологии, он считает, что если сегодня чётный день, то он счастливый, а если нет,  то плохой. Помогите Васе, напишите программу, которая по введенному дню будет определять счастливый он или нет
#
# По введённому номеру дня в месяце необходимо вывести HAPPY, ecли день предположительно будет счастливым, и BAD в ином случае
#
# **Входные данные**
# 1
# **Выходные данные**
# BAD
#
# **Входные данные**
# 2
# **Выходные данные**
# HAPPY

# %%
x = int(input())
if x % 2 == 0:
    print('HAPPY')
else:
    print('BAD')
# Out:
# HAPPY

# %% [markdown]
# ### Задание 11 (победное)
#
# Ваня и его друзья собрались, чтобы поиграть в интересную игру, все называют по очереди положительные числа. Когда кто-то говорит «0», следующий за ним, должен сказать самое большое число, которое звучало до этого. Напишите программу, которая поможет Ване выиграть в эту игру, если перед ним назовут 0.
#
# Вводятся числа по одному в новой строке последним вводится ноль
# Необходимо вывести самое большое число среди тех, которые были введены
#
# **Входные данные**
# 10
# 1
# 32
# 12
# 1
# 0
#
# **Выходные данные**
# 32

# %%
# ваше решение здесь
n_max = int(input())

while True:
    n = int(input())
    if n == 0:
        break
    else:
        if n > n_max:
            n_max = n
print(n_max)
# Out:
# 32

# %% [markdown]
# ## Задание 12 (поисковое)
# Последовательность состоит из натуральных чисел и завершается числом 0. Определите, сколько элементов этой последовательности больше предыдущего элемента.
#
# **Формат ввода:**
# Вводится последовательность целых чисел, оканчивающаяся числом 0 (само число 0 в последовательность не входит, а служит как признак ее окончания).
#
# **Формат вывода:**
# Выведите ответ на задачу.
#
# *Подсказка*
# Обработайте первое число до цикла и сохраните его в отдельную переменную (предыдущее число). Проверьте, что ваша программа правильно работает для пустой последовательности.
#
# Также для тренировки попробуйте решить задачу со списками и без
#
# **Пример ввода:**
#
# 1
# 7
# 9
# 0
#
# **Пример вывода:**
# 2

# %%
# решение здесь
count = 0
n_previous = int(input())
while True:
    n = int(input())
    if n == 0:
        break
    else:
        if n > n_previous:
            count += 1
            
print(count)

# %% [markdown]
# ### Задание 13 (ступенчатое)
# По данному натуральному n≤9 выведите лесенку из n ступенек, i-я ступенька состоит из чисел от 1 до i без пробелов.
#
# **Формат ввода:**
# Вводится натуральное число.
#
# **Формат вывода:**
# Выведите ответ на задачу.
#
# **Пример ввода:**
#
# 3
#
# **Пример вывода:**
# 1
# 12
# 123

# %%
# ваше решение здесь
x = int(input())
cnt = 1
cnt2 = 0


while cnt != x + 1:
    cnt2 = 0
    while cnt2 != cnt:
        cnt2 += 1
        print(cnt2, end = '')
    print()
    cnt += 1
# Out:
# 1
# 12
# 123
# 1234
# 12345
# 123456
# 1234567
# 12345678
# 123456789
# 12345678910

# %% [markdown]
# ## Задание 14 (олимпиадное)
#
# В олимпиаде по программированию задачи имеют три уровная сложности: "базовый" (б), "повышенный" (п) и "сложный" (c). Максимальное количество баллов, которое можно получить за каждую задачу составляет  **10,** однако, задачи имеют веса в зависимости от уровня сложности. Задачи базового уровня имеют вес **1**, повышенного - **1,5**, а сложного - **3** (количество баллов, полученных участником, умножается на "вес" задачи). Необходимо определить суммарное количество набранных баллов.
#
# **Формат ввода:**
#
# *   Множество пар вида “уровень задачи(буква) - набранное количество баллов (действительное число)”. Количество таких пар может быть разным.
# Каждая пара вводится с новой строки, ввод заканчивается нулем.
#
# **Формат вывода:**
#
# *   Действительное число (сумма баллов).
#
# **Пример:**
#
# **Ввод:**
#
# б 2
# п 2
# с 4
# с 7
# б 1
# 0
#
# **Вывод:**
#
# 39.0

# %%
# решение здесь
total = 0
while True:
    n = input().split()
    if n[0] == '0':
        break
    else:
        if n[0] == 'б':
            total += int(n[1])
        elif n[0] == 'п':
            total += int(n[1]) * 1.5
        else:
            total += int(n[1]) * 3
            
print(total)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-34ea878b0930> in <module>()
#      11             total += int(n[1]) * 1.5
#      12         else:
# ---> 13             total += int(n[1]) * 3
#      14
#      15 print(total)
#
# IndexError: list index out of range

# %% [markdown]
# ## Задание 15 (самоизоляционное)
# Вася начал бегать на месте и в первый день он пробежал X километров и выдохся. Вася поставил себе цель Y километров и решил узнать, когда он ее достигнет, если каждый день будет бегать дистанцию на 10% больше, чем в предыдущий.
#
# **Формат ввода**
#
# Программа получает на вход целые числа X, Y
#
# **Формат вывода**
#
# Одно целое число (день, когда Вася пробежит свою цель)
#
# **Примеры**
# **Ввод:**
# 10
# 21
#
# **Вывод:**
# 9

# %%
# решение здесь
x = int(input())
y = int(input())
day = 1
while x < y:
    x += 0.1*x
    day += 1
print(day)
